# %% [markdown]
# This note book measures the grpc operation efficiency.

# %%
import sys
sys.path.append('../bfrt_grpc')
from bfrt_grpc_client import Bfrt_GRPC_Client
from bfrt_grpc_client import ip_to_int, int_to_ip
from bfrt_grpc_client import gc
import time
import pandas as pd
import random

# %%
controller = Bfrt_GRPC_Client()
# Out:
# Subscribe attempt #1
# Subscribe response received 0
# Received tf_honeypot on GetForwarding on client 0, device 0
# Binding with p4_name tf_honeypot
# Binding with p4_name tf_honeypot successful!!

# %% [markdown]
# ## installation time for different batch size
# 1. sorted entry (exact match)

# %%
IP_INT_MIN = 0
IP_INT_MAX = 2**32 - 1

# %%
def test_entry_batch_add(controller, entry_key_list):
    key_list = []
    data_list = []
    for index, key in enumerate(entry_key_list):
        if (key[0], key[1], key[2]) in controller.installed_flow_key:
            continue
        key_list.append(controller.service_table.make_key([gc.KeyTuple("meta.internal_ip", key[0]),
                                                            gc.KeyTuple("meta.internal_port", key[1]),
                                                            gc.KeyTuple("meta.ip_protocol", key[2])]))
        controller.installed_flow_key.add((key[0], key[1], key[2]))
        data_list.append(controller.service_table.make_data([gc.DataTuple('$ENTRY_TTL', 2000)], 
                                                            'Ingress.drop'))
    start_time = time.time()
    controller.service_table.entry_add(controller.target, key_list, data_list)
    end_time = time.time()
    return end_time - start_time

def test_entry_batch_remove(controller, entry_key_list):
    key_list = []
    for index, key in enumerate(entry_key_list):
        if (key[0], key[1], key[2]) in controller.installed_flow_key:
            continue
        key_list.append(controller.service_table.make_key([gc.KeyTuple("meta.internal_ip", key[0]),
                                                    gc.KeyTuple("meta.internal_port", key[1]),
                                                    gc.KeyTuple("meta.ip_protocol", key[2])]))
        controller.installed_flow_key.add((key[0], key[1], key[2]))

    start_time = time.time()
    controller.service_table.entry_del(controller.target, key_list)
    end_time = time.time()
    return end_time - start_time


def test_idle_entry_batch_clean(controller, entry_key_list):

    key_list = []
    count = 0
    retry = 0

    while len(key_list) < len(entry_key_list):
        try:
            time1 = time.time()
            idle_notification = controller.interface.idletime_notification_get(timeout=0.2)
            recv_key = controller.bfrt_info.key_from_idletime_notification(idle_notification)
            key_dict = recv_key.to_dict()
            ip = key_dict["meta.internal_ip"]['value']
            port = key_dict["meta.internal_port"]['value']
            protocol = key_dict["meta.ip_protocol"]['value']
            time2 = time.time()
            controller.installed_flow_key.remove((ip_to_int(ip), port, protocol))

            key_list.append(recv_key)
            count += 1
        except RuntimeError as e:
            print(e, retry)
            retry += 1
            if retry >= 3:
                return -1
        except KeyError as e:
            pass
        
    if len(key_list) > 0:
        time3 = time.time()
        controller.service_table.entry_del(controller.target, key_list)
        time4 = time.time()
    
    return time4 - time3 + time2 - time1

def clean_notification(controller):
    while True:
        try:
            idle_notification = controller.interface.idletime_notification_get(timeout=0.2)
            recv_key = controller.bfrt_info.key_from_idletime_notification(idle_notification)
            key_dict = recv_key.to_dict()
            ip = key_dict["meta.internal_ip"]['value']
            port = key_dict["meta.internal_port"]['value']
            protocol = key_dict["meta.ip_protocol"]['value']
            controller.installed_flow_key.remove((ip_to_int(ip), port, protocol))
        except RuntimeError as e:
            print(e)
            break
        except KeyError as e:
            pass

# %%
controller.clear_service_table()
time_list = []

for experiment_index in range(3):
    for a in range(0, 5):
        for b in range(1, 10):
            controller.clear_service_table()
            
            batch_size = b * pow(10, a)
            if batch_size > 500000:
                break

            test_key_list = []
            for i in range(batch_size):
                test_key_list.append([167772161+i+1, experiment_index*60+a+b, experiment_index*60+a+b])
            
            add_time = test_entry_batch_add(controller, test_key_list)
            print(f"add_time: {add_time}")

            time.sleep(add_time+5)
            del_time = test_entry_batch_remove(controller, test_key_list)
            print(f"del_time: {del_time}")

            controller.clear_service_table()
            clean_notification(controller)

            # one wired thing is that when adding entries just deleted, nothing will be added
            test_key_list = []
            for i in range(batch_size):
                test_key_list.append([167772161+i+1, experiment_index*60+a+b+500, experiment_index*60+a+b])
            
            # test notification
            print("start add again")
            _ = test_entry_batch_add(controller, test_key_list)
            time.sleep(add_time+5)
            print("start clean")
            clean_time = test_idle_entry_batch_clean(controller, test_key_list)
            print(f"clean_time: {clean_time}")
            
            time_list.append({"experiment_index": experiment_index,
                              "batch_size": batch_size, 
                                "add_time": add_time,
                                "del_time": del_time,
                                "clean_time": clean_time,
                                "add_time_per_entry": add_time / batch_size,
                                "del_time_per_entry": del_time / batch_size,
                                "clean_time_per_entry": clean_time / batch_size})
            print(f"batch_size: {batch_size}, add_time: {add_time}, del_time: {del_time}, clean_time: {clean_time}")
    print(f"-----------------------experiment {experiment_index} finished-----------------")

    time_df = pd.DataFrame(time_list)
    time_df.to_csv("./results/grpc_result/entry_add_sorted.csv", index=False)

# %% [markdown]
# random entry

# %%
controller.clear_service_table()
time_list = []

for experiment_index in range(3):
    for a in range(0, 5):
        for b in range(1, 10):
            controller.clear_service_table()
            
            batch_size = b * pow(10, a)
            if batch_size > 500000:
                break

            test_key_list = []
            for i in range(batch_size):
                test_key_list.append([random.randint(167772161, 335544321), experiment_index*60+a+b, experiment_index*60+a+b])
            
            add_time = test_entry_batch_add(controller, test_key_list)
            print(f"add_time: {add_time}")

            time.sleep(add_time+5)
            del_time = test_entry_batch_remove(controller, test_key_list)
            print(f"del_time: {del_time}")

            controller.clear_service_table()
            clean_notification(controller)

            # one wired thing is that when adding entries just deleted, nothing will be added
            test_key_list = []
            for i in range(batch_size):
                test_key_list.append([random.randint(503316481, 671088641), experiment_index*60+a+b+500, experiment_index*60+a+b])
            
            # test notification
            print("start add again")
            _ = test_entry_batch_add(controller, test_key_list)
            time.sleep(add_time+20)
            print("start clean")
            clean_time = test_idle_entry_batch_clean(controller, test_key_list)
            print(f"clean_time: {clean_time}")
            
            time_list.append({"experiment_index": experiment_index,
                              "batch_size": batch_size, 
                                "add_time": add_time,
                                "del_time": del_time,
                                "clean_time": clean_time,
                                "add_time_per_entry": add_time / batch_size,
                                "del_time_per_entry": del_time / batch_size,
                                "clean_time_per_entry": clean_time / batch_size})
            print(f"batch_size: {batch_size}, add_time: {add_time}, del_time: {del_time}, clean_time: {clean_time}")
    print(f"-----------------------experiment {experiment_index} finished-----------------")

    time_df = pd.DataFrame(time_list)
    time_df.to_csv("./results/grpc_result/entry_add_random.csv", index=False)
# Out:
# add_time: 0.019280672073364258
# del_time: 0.0031833648681640625
# Idletime notification not received
# start add again
# start clean
# clean_time: 0
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.008390426635742188
# batch_size: 70, add_time: 0.009622812271118164, del_time: 0.005740642547607422, clean_time: 0.008390426635742188
# add_time: 0.010587453842163086
# del_time: 0.0060443878173828125
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.008870124816894531
# batch_size: 80, add_time: 0.010587453842163086, del_time: 0.0060443878173828125, clean_time: 0.008870124816894531
# add_time: 0.011530399322509766
# del_time: 0.006160736083984375
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.009623527526855469
# batch_size: 90, add_time: 0.011530399322509766, del_time: 0.006160736083984375, clean_time: 0.009623527526855469
# add_time: 0.01267695426940918
# del_time: 0.006300449371337891
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.010505437850952148
# batch_size: 100, add_time: 0.01267695426940918, del_time: 0.006300449371337891, clean_time: 0.010505437850952148
# add_time: 0.022746562957763672
# del_time: 0.00897669792175293
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.016568422317504883
# batch_size: 200, add_time: 0.022746562957763672, del_time: 0.00897669792175293, clean_time: 0.016568422317504883
# add_time: 0.031785011291503906
# del_time: 0.011196613311767578
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.02413463592529297
# batch_size: 300, add_time: 0.031785011291503906, del_time: 0.011196613311767578, clean_time: 0.02413463592529297
# add_time: 0.03893613815307617
# del_time: 0.014159917831420898
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.027135133743286133
# batch_size: 400, add_time: 0.03893613815307617, del_time: 0.014159917831420898, clean_time: 0.027135133743286133
# add_time: 0.046015024185180664
# del_time: 0.014695405960083008
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.032395124435424805
# batch_size: 500, add_time: 0.046015024185180664, del_time: 0.014695405960083008, clean_time: 0.032395124435424805
# add_time: 0.05616402626037598
# del_time: 0.016869306564331055
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.03772544860839844
# batch_size: 600, add_time: 0.05616402626037598, del_time: 0.016869306564331055, clean_time: 0.03772544860839844
# add_time: 0.06538009643554688
# del_time: 0.019710063934326172
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.04372692108154297
# batch_size: 700, add_time: 0.06538009643554688, del_time: 0.019710063934326172, clean_time: 0.04372692108154297
# add_time: 0.06999611854553223
# del_time: 0.02225804328918457
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.05102396011352539
# batch_size: 800, add_time: 0.06999611854553223, del_time: 0.02225804328918457, clean_time: 0.05102396011352539
# add_time: 0.07578301429748535
# del_time: 0.024132490158081055
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.05572152137756348
# batch_size: 900, add_time: 0.07578301429748535, del_time: 0.024132490158081055, clean_time: 0.05572152137756348
# add_time: 0.08348536491394043
# del_time: 0.025549650192260742
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.05930638313293457
# batch_size: 1000, add_time: 0.08348536491394043, del_time: 0.025549650192260742, clean_time: 0.05930638313293457
# add_time: 0.16063547134399414
# del_time: 0.04048514366149902
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.10662484169006348
# batch_size: 2000, add_time: 0.16063547134399414, del_time: 0.04048514366149902, clean_time: 0.10662484169006348
# add_time: 0.23017239570617676
# del_time: 0.05608773231506348
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.15277528762817383
# batch_size: 3000, add_time: 0.23017239570617676, del_time: 0.05608773231506348, clean_time: 0.15277528762817383
# add_time: 0.3028223514556885
# del_time: 0.06830096244812012
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.19620203971862793
# batch_size: 4000, add_time: 0.3028223514556885, del_time: 0.06830096244812012, clean_time: 0.19620203971862793
# add_time: 0.3756442070007324
# del_time: 0.0824897289276123
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.23680615425109863
# batch_size: 5000, add_time: 0.3756442070007324, del_time: 0.0824897289276123, clean_time: 0.23680615425109863
# add_time: 0.4385414123535156
# del_time: 0.09692859649658203
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.2865266799926758
# batch_size: 6000, add_time: 0.4385414123535156, del_time: 0.09692859649658203, clean_time: 0.2865266799926758
# add_time: 0.5135209560394287
# del_time: 0.10816335678100586
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.34063172340393066
# batch_size: 7000, add_time: 0.5135209560394287, del_time: 0.10816335678100586, clean_time: 0.34063172340393066
# add_time: 0.5811901092529297
# del_time: 0.12491607666015625
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.37775516510009766
# batch_size: 8000, add_time: 0.5811901092529297, del_time: 0.12491607666015625, clean_time: 0.37775516510009766
# add_time: 0.6479964256286621
# del_time: 0.14294791221618652
# Idletime notification not received
# start add again
# start clean
# Idletime notification not received 0
# Idletime notification not received 1
# Idletime notification not received 2
# clean_time: -1
# batch_size: 9000, add_time: 0.6479964256286621, del_time: 0.14294791221618652, clean_time: -1
# add_time: 0.7219641208648682
# del_time: 0.15267491340637207
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.47266292572021484
# batch_size: 10000, add_time: 0.7219641208648682, del_time: 0.15267491340637207, clean_time: 0.47266292572021484
# add_time: 1.4569320678710938
# del_time: 0.295590877532959
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.9269917011260986
# batch_size: 20000, add_time: 1.4569320678710938, del_time: 0.295590877532959, clean_time: 0.9269917011260986
# add_time: 2.142357110977173
# del_time: 0.45528650283813477
# Idletime notification not received
# start add again
# start clean
# Idletime notification not received 0
# Idletime notification not received 1
# Idletime notification not received 2
# clean_time: -1
# batch_size: 30000, add_time: 2.142357110977173, del_time: 0.45528650283813477, clean_time: -1
# add_time: 2.8941259384155273
# del_time: 0.5919022560119629
# Idletime notification not received
# start add again
# start clean
# Idletime notification not received 0
# Idletime notification not received 1
# Idletime notification not received 2
# clean_time: -1
# batch_size: 40000, add_time: 2.8941259384155273, del_time: 0.5919022560119629, clean_time: -1
# add_time: 3.6105093955993652
# del_time: 0.760033369064331
# Idletime notification not received
# start add again
# start clean
# Idletime notification not received 0
# Idletime notification not received 1
# Idletime notification not received 2
# clean_time: -1
# batch_size: 50000, add_time: 3.6105093955993652, del_time: 0.760033369064331, clean_time: -1
# add_time: 4.343064308166504
# del_time: 0.9080979824066162
# Idletime notification not received
# start add again
# start clean
# Idletime notification not received 0
# Idletime notification not received 1
# Idletime notification not received 2
# clean_time: -1
# batch_size: 60000, add_time: 4.343064308166504, del_time: 0.9080979824066162, clean_time: -1
# add_time: 5.0841474533081055
# del_time: 1.055858850479126
# Idletime notification not received
# start add again
# start clean
# Idletime notification not received 0
# Idletime notification not received 1
# Idletime notification not received 2
# clean_time: -1
# batch_size: 70000, add_time: 5.0841474533081055, del_time: 1.055858850479126, clean_time: -1
# add_time: 5.788251638412476
# del_time: 1.2308509349822998
# Idletime notification not received
# start add again
# start clean
# Idletime notification not received 0
# Idletime notification not received 1
# Idletime notification not received 2
# clean_time: -1
# batch_size: 80000, add_time: 5.788251638412476, del_time: 1.2308509349822998, clean_time: -1
# add_time: 6.439684629440308
# del_time: 1.3521783351898193
# Idletime notification not received
# start add again
# start clean
# Idletime notification not received 0
# Idletime notification not received 1
# Idletime notification not received 2
# clean_time: -1
# batch_size: 90000, add_time: 6.439684629440308, del_time: 1.3521783351898193, clean_time: -1
# -----------------------experiment 0 finished-----------------
# add_time: 0.002369403839111328
# del_time: 0.002598285675048828
# Idletime notification not received
# start add again
# start clean
# clean_time: 0
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.007883071899414062
# batch_size: 60, add_time: 0.008131027221679688, del_time: 0.0053327083587646484, clean_time: 0.007883071899414062
# add_time: 0.009490013122558594
# del_time: 0.005524158477783203
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.008385658264160156
# batch_size: 70, add_time: 0.009490013122558594, del_time: 0.005524158477783203, clean_time: 0.008385658264160156
# add_time: 0.010337591171264648
# del_time: 0.005855083465576172
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.009037971496582031
# batch_size: 80, add_time: 0.010337591171264648, del_time: 0.005855083465576172, clean_time: 0.009037971496582031
# add_time: 0.011107683181762695
# del_time: 0.005902767181396484
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.009745359420776367
# batch_size: 90, add_time: 0.011107683181762695, del_time: 0.005902767181396484, clean_time: 0.009745359420776367
# add_time: 0.012812376022338867
# del_time: 0.005957841873168945
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.010189056396484375
# batch_size: 100, add_time: 0.012812376022338867, del_time: 0.005957841873168945, clean_time: 0.010189056396484375
# add_time: 0.02212810516357422
# del_time: 0.008816957473754883
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.016652822494506836
# batch_size: 200, add_time: 0.02212810516357422, del_time: 0.008816957473754883, clean_time: 0.016652822494506836
# add_time: 0.032271623611450195
# del_time: 0.011571168899536133
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.022721052169799805
# batch_size: 300, add_time: 0.032271623611450195, del_time: 0.011571168899536133, clean_time: 0.022721052169799805
# add_time: 0.038808345794677734
# del_time: 0.013793706893920898
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.026810169219970703
# batch_size: 400, add_time: 0.038808345794677734, del_time: 0.013793706893920898, clean_time: 0.026810169219970703
# add_time: 0.04592394828796387
# del_time: 0.0160677433013916
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.033434391021728516
# batch_size: 500, add_time: 0.04592394828796387, del_time: 0.0160677433013916, clean_time: 0.033434391021728516
# add_time: 0.051004648208618164
# del_time: 0.01658153533935547
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.0370936393737793
# batch_size: 600, add_time: 0.051004648208618164, del_time: 0.01658153533935547, clean_time: 0.0370936393737793
# add_time: 0.06150245666503906
# del_time: 0.01975226402282715
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.043435096740722656
# batch_size: 700, add_time: 0.06150245666503906, del_time: 0.01975226402282715, clean_time: 0.043435096740722656
# add_time: 0.06876659393310547
# del_time: 0.02052760124206543
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.04836773872375488
# batch_size: 800, add_time: 0.06876659393310547, del_time: 0.02052760124206543, clean_time: 0.04836773872375488
# add_time: 0.07422924041748047
# del_time: 0.021007299423217773
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.05259871482849121
# batch_size: 900, add_time: 0.07422924041748047, del_time: 0.021007299423217773, clean_time: 0.05259871482849121
# add_time: 0.08437252044677734
# del_time: 0.02362656593322754
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.054472923278808594
# batch_size: 1000, add_time: 0.08437252044677734, del_time: 0.02362656593322754, clean_time: 0.054472923278808594
# add_time: 0.16051030158996582
# del_time: 0.03789877891540527
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.10637760162353516
# batch_size: 2000, add_time: 0.16051030158996582, del_time: 0.03789877891540527, clean_time: 0.10637760162353516
# add_time: 0.2290654182434082
# del_time: 0.053626060485839844
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.15044045448303223
# batch_size: 3000, add_time: 0.2290654182434082, del_time: 0.053626060485839844, clean_time: 0.15044045448303223
# add_time: 0.301161527633667
# del_time: 0.06453275680541992
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.19706392288208008
# batch_size: 4000, add_time: 0.301161527633667, del_time: 0.06453275680541992, clean_time: 0.19706392288208008
# add_time: 0.3669402599334717
# del_time: 0.08285951614379883
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.24437761306762695
# batch_size: 5000, add_time: 0.3669402599334717, del_time: 0.08285951614379883, clean_time: 0.24437761306762695
# add_time: 0.44188404083251953
# del_time: 0.09772944450378418
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.2944815158843994
# batch_size: 6000, add_time: 0.44188404083251953, del_time: 0.09772944450378418, clean_time: 0.2944815158843994
# add_time: 0.5189108848571777
# del_time: 0.11339712142944336
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.3343360424041748
# batch_size: 7000, add_time: 0.5189108848571777, del_time: 0.11339712142944336, clean_time: 0.3343360424041748
# add_time: 0.5787301063537598
# del_time: 0.12595224380493164
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.3853588104248047
# batch_size: 8000, add_time: 0.5787301063537598, del_time: 0.12595224380493164, clean_time: 0.3853588104248047
# add_time: 0.6539390087127686
# del_time: 0.13784241676330566
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.44288015365600586
# batch_size: 9000, add_time: 0.6539390087127686, del_time: 0.13784241676330566, clean_time: 0.44288015365600586
# add_time: 0.7372992038726807
# del_time: 0.1527707576751709
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.4921529293060303
# batch_size: 10000, add_time: 0.7372992038726807, del_time: 0.1527707576751709, clean_time: 0.4921529293060303
# add_time: 1.492434024810791
# del_time: 0.30289506912231445
# Idletime notification not received
# start add again
# start clean
# clean_time: 0.9732978343963623
# batch_size: 20000, add_time: 1.492434024810791, del_time: 0.30289506912231445, clean_time: 0.9732978343963623
# add_time: 2.207766532897949
# del_time: 0.44130373001098633
# Idletime notification not received
# start add again
# start clean
# Idletime notification not received 0
# Idletime notification not received 1
# Idletime notification not received 2
# clean_time: -1
# batch_size: 30000, add_time: 2.207766532897949, del_time: 0.44130373001098633, clean_time: -1
# add_time: 2.9326400756835938
# del_time: 0.5946857929229736
# Idletime notification not received
# start add again
# start clean
# Idletime notification not received 0
# Idletime notification not received 1
# Idletime notification not received 2
# clean_time: -1
# batch_size: 40000, add_time: 2.9326400756835938, del_time: 0.5946857929229736, clean_time: -1
# add_time: 3.5925211906433105
# del_time: 0.7621815204620361
# Idletime notification not received
# start add again
# start clean
# Idletime notification not received 0
# Idletime notification not received 1
# Idletime notification not received 2
# clean_time: -1
# batch_size: 50000, add_time: 3.5925211906433105, del_time: 0.7621815204620361, clean_time: -1
# add_time: 4.344982147216797
# del_time: 0.9066286087036133
# Idletime notification not received
# start add again
# start clean
# Idletime notification not received 0
# Idletime notification not received 1
# Idletime notification not received 2
# clean_time: -1
# batch_size: 60000, add_time: 4.344982147216797, del_time: 0.9066286087036133, clean_time: -1
# add_time: 5.055596590042114
# del_time: 1.0739946365356445
# Idletime notification not received
# start add again
# start clean
# Idletime notification not received 0
# Idletime notification not received 1
# Idletime notification not received 2
# clean_time: -1
# batch_size: 70000, add_time: 5.055596590042114, del_time: 1.0739946365356445, clean_time: -1
# add_time: 5.808245897293091
# del_time: 1.2164185047149658
# Idletime notification not received
# start add again
# start clean
# Idletime notification not received 0
# Idletime notification not received 1
# Idletime notification not received 2
# clean_time: -1
# batch_size: 80000, add_time: 5.808245897293091, del_time: 1.2164185047149658, clean_time: -1

# %%
ip_to_int('40.0.0.1')
# Out:
# 671088641
